# %%
#must use this numpy version due to eval compatability
# !pip install numpy==1.17.0

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#moving to the desired position on drive
# %cd drive/MyDrive/tf/model2

# %%
# downloading the object detection repo from github
import os
import pathlib

# !git clone --depth 1 https://github.com/tensorflow/models

# %%
# Install the Object Detection API
# %cd models/research/
# !protoc object_detection/protos/*.proto --python_out=.
# Install TensorFlow Object Detection API.
# !cp object_detection/packages/tf2/setup.py .
# !python -m pip install .

# %%
#run model builder test
# %cd ../../..
# !python model2/models/research/object_detection/builders/model_builder_tf2_test.py

# %%
#Where to put the eval data, path to the config file and checkpoint path
model_dir = 'training_data/training_ssd_mobilenet_v2/'
pipeline_config_path = 'model_config.config'
cpt_dir = model_dir

# %%
# Evaluation script has to run at the same time as training to be able to run at all checkpoints when they appear in the folder

# %%
# !python model2/models/research/object_detection/model_main_tf2.py \
    --pipeline_config_path={pipeline_config_path} \
    --model_dir={model_dir} \
    --checkpoint_dir={cpt_dir}\
    --alsologtostderr \

# %%
# %load_ext tensorboard
# %tensorboard --logdir 'training_data/training_ssd_mobilenet_v2/eval'
